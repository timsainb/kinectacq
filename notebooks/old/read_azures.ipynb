# %%
# %load_ext autoreload
# %autoreload 2

# %%
import subprocess, cv2, json, os, sys, shutil, pyk4a, time
import numpy as np, matplotlib.pyplot as plt
from kinectacq.acquisition import start_recording
from kinectacq.paths import DATA_DIR, ensure_dir

# %% [markdown]
# ### Set up recording location and duration info

# %%
import datetime

# %%
import pathlib2

# %%
filename_prefix = DATA_DIR / 'test_recording'

# %%
recording_dirs = np.sort(list(filename_prefix.glob('*')))

# %%
recording_dir = recording_dirs[-1]
recording_dir
# Out:
# PosixPath('/home/tim/Projects/azure_acquisition_template/data/test_recording/2022-02-07_15-36-57')

# %%
depth_file = recording_dir / 'master' / 'depth.avi'
ir_file = recording_dir / 'master' / 'ir.avi'

# %%
from kinectacq.video_io import read_frames

# %%
sample_frames = read_frames(
    filename=depth_file,
    frames = np.arange(30*5),
    pixel_format="gray8",
    frame_size=(640, 576),
    slices=24,
    slicecrc=1,
    get_cmd=False,
)

# %%
sample_frames.shape
# Out:
# (150, 576, 640)

# %%
plt.matshow(sample_frames[-1])
plt.matshow(sample_frames[-1])

# %%
plt.hist(sample_frames[-1].flatten())
# Out:
# (array([3.20106e+05, 9.00000e+01, 1.16400e+03, 2.81900e+03, 6.64800e+03,
#         8.92800e+03, 2.13330e+04, 6.80900e+03, 5.90000e+02, 1.53000e+02]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)
