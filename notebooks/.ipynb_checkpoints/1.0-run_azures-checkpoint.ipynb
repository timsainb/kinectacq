# %%
# %load_ext autoreload
# %autoreload 2

# %%
import subprocess, cv2, json, os, sys, shutil, pyk4a, time
import numpy as np, matplotlib.pyplot as plt
from kinectacq.acquisition import start_recording
from kinectacq.paths import DATA_DIR, ensure_dir

# %% [markdown]
# ### Set up recording location

# %%
import datetime

# %%
timestamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
timestamp
# Out:
# '2022-03-02_10-31-32'

# %%
filename_prefix = DATA_DIR / 'test_recording' / timestamp

# %%
ensure_dir(filename_prefix)

# %% [markdown]
# ### Get camera information

# %%
# !k4arecorder --list
# Out:
# Index:0	Serial:000774310512	Color:1.6.102	Depth:1.6.75

# %% [markdown]
# ### Set up devices
# - each k4a device needs to be configured
# - multi-camera rigs need to set up the WiredSyncMode
#     - Master = WiredSyncMode.MASTER
#     - Subordinate = WiredSyncMode.SUBORDINATE
#     - subordinate_delay_off_master_usec=640 (master samples every 900usec)
# - [Kinect SDK](https://microsoft.github.io/Azure-Kinect-Sensor-SDK/master/structk4a__device__configuration__t_a8208974f05d89fc1362c6a0900bdef4d.html#a8208974f05d89fc1362c6a0900bdef4d)

# %%
from pyk4a import (
    PyK4A,
    Config,
    ColorResolution,
    DepthMode,
    WiredSyncMode,
)

# %%
devices = {
    "master": {
        "id": 0,
        "pyk4a_config": {
            "color_resolution": ColorResolution.RES_720P,
            "depth_mode": DepthMode.NFOV_UNBINNED,
            #"synchronized_images_only": False,
            #"wired_sync_mode": WiredSyncMode.MASTER,
        },
        "process_kwargs": {
            "display_frames": True,
            "display_time": True,
            "save_color": True,
        },
    }
}

# %% [markdown]
# ### Set up processing functions
# - Functions for reducing video file sizes to 8 bit.

# %%
_dtype = np.uint16

# %%
def process_depth(depth):
    #return np.clip((depth - 435) * (depth < 690), 0, 255).astype(_dtype)
    return depth.astype(_dtype)
def process_ir(ir):
    #ir = np.clip(ir + 100, 160, 5500)
    #return ((np.log(ir) - 5) * 70).astype(_dtype)
    return ir.astype(_dtype)

# %% [markdown]
# ### Recording parameters

# %%
ir_depth_write_frames_kwargs={
        "codec": "ffv1", #"ffv1",
        "crf": 14,
        "threads": 8,
        "fps": 30,
        "slices": 24,
        "slicecrc": 1,
        "frame_size": None,
        "get_cmd": False,
    }

# %%
color_write_frames_kwargs={
        "codec": "ffv1", #"h264",
        "crf": 22,
        "threads": 8,
        "fps": 30,
        "slices": 24,
        "slicecrc": 1,
        "frame_size": None,
        "get_cmd": False,
    }

# %%
recording_duration = 20

# %% [markdown]
# ### Run recording

# %%
start_recording(
    filename_prefix,
    recording_duration,
    devices=devices,
    depth_function = process_depth,
    ir_function = process_ir,
    ir_depth_dtype = _dtype,
    ir_depth_write_frames_kwargs=ir_depth_write_frames_kwargs,
    color_write_frames_kwargs=color_write_frames_kwargs
)
# Out:
# master (frames written):   0%|          | 0/600 [00:00<?, ?it/s]
# Recording (s):   0%|          | 0/20 [00:00<?, ?it/s]
# capture_from_azure initialized: master
#  Exiting: KeyboardInterrupt
# Recording stopped early
# Pipe broken for depth_repipe
#   continuing on to depth_repipe_repipe
# Framerate (master):30.1081
# Pipe broken for ir_repipe
#   continuing on to ir_repipe_repipe
# Pipe broken for color_repipe
#   continuing on to color_repipe_repipe
#  Finished writing (master): 2022-03-02 11:41:28.136408

# %%
# check if anything is still writing
for device in devices:
    is_writing = np.load(filename_prefix/device/"is_writing.npy")[0]
    print("device {}:".format(device), is_writing)
    if is_writing:
        raise ValueError('Wait until start_recording finishes')
# Out:
# device master: False

# %% [markdown]
# ### Read and show file

# %%
print('\n'.join([i.as_posix() for i in list((filename_prefix/'master').iterdir())]))
# Out:
# /n/groups/datta/tim_sainburg/projects/kinectacq/data/test_recording/2022-03-02_10-31-32/master/color.avi
# /n/groups/datta/tim_sainburg/projects/kinectacq/data/test_recording/2022-03-02_10-31-32/master/ir.avi
# /n/groups/datta/tim_sainburg/projects/kinectacq/data/test_recording/2022-03-02_10-31-32/master/calibration.json
# /n/groups/datta/tim_sainburg/projects/kinectacq/data/test_recording/2022-03-02_10-31-32/master/system_timestamps.npy
# /n/groups/datta/tim_sainburg/projects/kinectacq/data/test_recording/2022-03-02_10-31-32/master/is_writing.npy
# /n/groups/datta/tim_sainburg/projects/kinectacq/data/test_recording/2022-03-02_10-31-32/master/depth.avi
# /n/groups/datta/tim_sainburg/projects/kinectacq/data/test_recording/2022-03-02_10-31-32/master/ir_repipe.avi
# /n/groups/datta/tim_sainburg/projects/kinectacq/data/test_recording/2022-03-02_10-31-32/master/ir_timestamps.npy
# /n/groups/datta/tim_sainburg/projects/kinectacq/data/test_recording/2022-03-02_10-31-32/master/depth_timestamps.npy
# /n/groups/datta/tim_sainburg/projects/kinectacq/data/test_recording/2022-03-02_10-31-32/master/depth_repipe.avi
# /n/groups/datta/tim_sainburg/projects/kinectacq/data/test_recording/2022-03-02_10-31-32/master/color_repipe.avi
# /n/groups/datta/tim_sainburg/projects/kinectacq/data/test_recording/2022-03-02_10-31-32/master/color_timestamps.npy

# %%
system_timestamps = np.load(filename_prefix / 'master' / 'system_timestamps.npy')

# %%
len(system_timestamps)
# Out:
# 413

# %%
len(system_timestamps) /((np.max(system_timestamps) - np.min(system_timestamps))*1e-9)
# Out:
# 30.10811647183983

# %%
((np.max(system_timestamps) - np.min(system_timestamps))*1e-9)
# Out:
# 13.717231378000001

# %%
depth_timestamps = np.load(filename_prefix / 'master' / 'depth_timestamps.npy')
system_timestamps = np.load(filename_prefix / 'master' / 'system_timestamps.npy')

# %%
plt.plot((system_timestamps[0] - system_timestamps)- depth_timestamps)

# %%
file_loc = filename_prefix / 'master' /  "depth.avi"
vidcap = cv2.VideoCapture(file_loc.as_posix())
success,image = vidcap.read()
total_frames = vidcap.get(7)
print(total_frames, image.shape)
# Out:
# 313.0 (576, 640, 3)

# %%
file_loc = filename_prefix / 'master' /  "depth_repipe.avi"
vidcap = cv2.VideoCapture(file_loc.as_posix())
success,image = vidcap.read()
total_frames = vidcap.get(7)
print(total_frames, image.shape)
# Out:
# 100.0 (576, 640, 3)

# %%
nbit = 16
total_expected_bits = total_frames * np.product(image.shape) * nbit
total_expected_MB_uncompressed = total_expected_bits * 1.192e-7 
GB_per_hour = os.path.getsize(file_loc) * 1e-9 * recording_duration/ 60*60
print('uncompressed size: {} MB'.format(round(total_expected_MB_uncompressed)))
print('actual_size: {} MB'.format(round(os.path.getsize(file_loc) * 1e-6)))
print('size per hour: {} GB'.format(round(GB_per_hour, 1)))
# Out:
# uncompressed size: 211 MB
# actual_size: 5 MB
# size per hour: 0.1 GB

# %%
# get frame at number
vidcap.set(1, 5)
success,image = vidcap.read()

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.matshow(np.log(1+image)[:,:,0])

# %%
file_loc = filename_prefix / 'master' /  "color.avi"
vidcap = cv2.VideoCapture(file_loc.as_posix())
success,image = vidcap.read()
total_frames = vidcap.get(7)
print(total_frames, image.shape)
# Out:
# 313.0 (720, 1280, 3)

# %%
nbit = 8
total_expected_bits = total_frames * np.product(image.shape) * nbit
total_expected_MB_uncompressed = total_expected_bits * 1.192e-7 
GB_per_hour = os.path.getsize(file_loc) * 1e-9 * recording_duration/ 60*60
print('uncompressed size: {} MB'.format(round(total_expected_MB_uncompressed)))
print('actual_size: {} MB'.format(round(os.path.getsize(file_loc) * 1e-6)))
print('size per hour: {} GB'.format(round(GB_per_hour, 1)))
# Out:
# uncompressed size: 825 MB
# actual_size: 174 MB
# size per hour: 3.5 GB

# %%
success,image = vidcap.read()
# get frame at number
vidcap.set(1, 4)
success,image = vidcap.read()

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(image)
